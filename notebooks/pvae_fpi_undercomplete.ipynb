# %%
# %cd ..
# Out:
# /home/eli/AnacondaProjects/wgvp_pc

# %%
import hydra
import math
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import numpy as np
import numpyro
from omegaconf import OmegaConf
import rootutils
import sys

# %%
from src import test, train

# %%
with hydra.initialize(version_base="1.3", config_path="../configs", job_name="eval"):
    cfg = hydra.compose(config_name="eval.yaml", overrides=["ckpt_path=logs/train/runs/2026-02-09_21-17-09/saved/checkpoint-epoch4000.npy",
                                                            "+experiment=pvae_fpi_undercomplete", "hydra.runtime.output_dir=logs/test"],
                        return_hydra_config=True)
    hydra.core.hydra_config.HydraConfig.instance().set_config(cfg)
    metrics, objects = test.test(cfg)

# %%
metrics
# Out:
# {'loss': np.float32(-64993.44),
#  'loss_batch_mean': np.float32(-507.76126),
#  'log_w': np.float32(56869.258),
#  'log_w_batch_mean': np.float32(444.29108)}

# %%
for data, _, _ in objects['datamodule'].test_dataloader():
    recons = objects['monad'](data)['x'].mean(axis=0).reshape(data.shape[0], 1, 28, 28)
    break
# Out:
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)

# %%
plt.imshow(recons[0].squeeze())

# %%
plt.imshow(data[0].squeeze())

# %%
objects['monad'].render_model()

# %%
def r2(xs, xs_hat):
    squared_errors = ((xs - xs_hat) ** 2).sum()
    total_squares = ((xs - xs.mean(axis=0, keepdims=True)) ** 2).sum()
    return 1.0 - squared_errors / (total_squares + jnp.finfo("float64").eps)

def portion_zeros(zs):
    return (zs == 0).mean()

# %%
xs, xs_hat, zs = [], [], []

for data, _, _ in objects['datamodule'].test_dataloader():
    traces = objects['monad'](data)
    recons = traces['x'].mean(axis=0).reshape(data.shape[0], 1, 28, 28)
    xs.append(data)
    xs_hat.append(recons)
    zs.append(traces["z"])

xs = jnp.concatenate(xs, axis=0)
xs_hat = jnp.concatenate(xs_hat, axis=0)
zs = jnp.concatenate(zs, axis=1)
# Out:
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)

# %%
portion_zeros(zs)
# Out:
# Array(0.7290336, dtype=float32)

# %%
r2(xs, xs_hat)
# Out:
# Array(0.89966583, dtype=float32)

# %%
xs.shape
# Out:
# (9984, 1, 28, 28)

# %%
with hydra.initialize(version_base="1.3", config_path="../configs", job_name="eval"):
    cfg = hydra.compose(config_name="eval.yaml", overrides=["ckpt_path=logs/train/runs/2026-02-09_21-17-09/saved/checkpoint-epoch4000.npy",
                                                            "+experiment=pvae_fpi_undercomplete", "data=omniglot", "hydra.runtime.output_dir=logs/test"],
                        return_hydra_config=True)
    hydra.core.hydra_config.HydraConfig.instance().set_config(cfg)
    metrics, objects = test.test(cfg)

# %%
metrics
# Out:
# {'loss': np.float32(-28843.037),
#  'loss_batch_mean': np.float32(-225.33623),
#  'log_w': np.float32(25237.656),
#  'log_w_batch_mean': np.float32(197.16919)}

# %%
for data, _, _ in objects['datamodule'].test_dataloader():
    recons = objects['monad'](data)['x'].mean(axis=0).reshape(data.shape[0], 1, 28, 28)
    break
# Out:
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)

# %%
plt.imshow(recons[0].squeeze())

# %%
plt.imshow(data[0].squeeze())

# %%
objects['monad'].render_model()

# %%
def r2(xs, xs_hat):
    squared_errors = ((xs - xs_hat) ** 2).sum()
    total_squares = ((xs - xs.mean(axis=0, keepdims=True)) ** 2).sum()
    return 1.0 - squared_errors / (total_squares + jnp.finfo("float64").eps)

def portion_zeros(zs):
    return (zs == 0).mean()

# %%
xs, xs_hat, zs = [], [], []

for data, _, _ in objects['datamodule'].test_dataloader():
    traces = objects['monad'](data)
    recons = traces['x'].mean(axis=0).reshape(data.shape[0], 1, 28, 28)
    xs.append(data)
    xs_hat.append(recons)
    zs.append(traces["z"])

xs = jnp.concatenate(xs, axis=0)
xs_hat = jnp.concatenate(xs_hat, axis=0)
zs = jnp.concatenate(zs, axis=1)
# Out:
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)

# %%
portion_zeros(zs)
# Out:
# Array(0.7466223, dtype=float32)

# %%
r2(xs, xs_hat)
# Out:
# Array(0.60848534, dtype=float32)

# %%
xs.shape
# Out:
# (13056, 1, 28, 28)
