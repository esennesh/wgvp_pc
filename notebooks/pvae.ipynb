# %%
# %cd ..
# Out:
# /home/eli/AnacondaProjects/wgvp_pc

# %%
import hydra
import math
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import numpy as np
import numpyro
from omegaconf import OmegaConf
import rootutils
import sys

# %%
from src import test, train

# %%
with hydra.initialize(version_base="1.3", config_path="../configs", job_name="eval"):
    cfg = hydra.compose(config_name="eval.yaml", overrides=["ckpt_path=logs/train/runs/2026-01-11_14-24-27/saved/checkpoint-epoch500.npy",
                                                            "+experiment=pvae", "hydra.runtime.output_dir=logs/test"], return_hydra_config=True)
    hydra.core.hydra_config.HydraConfig.instance().set_config(cfg)
    metrics, objects = test.test(cfg)

# %%
metrics
# Out:
# {'loss': np.float32(-61545.883),
#  'loss_batch_mean': np.float32(-480.8272),
#  'log_w': np.float32(53852.64),
#  'log_w_batch_mean': np.float32(420.72375)}

# %%
for data, _, _ in objects['datamodule'].test_dataloader():
    recons = objects['monad'](data)['x'].mean(axis=0).reshape(data.shape[0], 1, 28, 28)
    break
# Out:
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)

# %%
plt.imshow(recons[0].squeeze())

# %%
plt.imshow(data[0].squeeze())

# %%
objects['monad'].render_model()

# %%
def r2(xs, xs_hat):
    squared_errors = ((xs - xs_hat) ** 2).sum()
    total_squares = ((xs - xs.mean(axis=0, keepdims=True)) ** 2).sum()
    return 1.0 - squared_errors / (total_squares + jnp.finfo("float64").eps)

def portion_zeros(zs):
    return (zs == 0).mean()

# %%
xs, xs_hat, zs = [], [], []

for data, _, _ in objects['datamodule'].test_dataloader():
    traces = objects['monad'](data)
    recons = traces['x'].mean(axis=0).reshape(data.shape[0], 1, 28, 28)
    xs.append(data)
    xs_hat.append(recons)
    zs.append(traces["z"])

xs = jnp.concatenate(xs, axis=0)
xs_hat = jnp.concatenate(xs_hat, axis=0)
zs = jnp.concatenate(zs, axis=1)
# Out:
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:79: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)

# %%
portion_zeros(zs)
# Out:
# Array(0.88444555, dtype=float32)

# %%
r2(xs, xs_hat)
# Out:
# Array(0.87758714, dtype=float32)

# %%
xs.shape
# Out:
# (9984, 1, 28, 28)

# %%
features = objects["monad"].parameters["decoder$params"]["kernel"] ** 2
ordering = zs.mean(axis=(0, 1)).argsort(axis=-1)[::-1]
features = features[ordering, :].reshape((-1, 28, 28))

# %%
from mpl_toolkits.axes_grid1 import ImageGrid

fig = plt.figure(figsize=(8, features.shape[0] / 8))
grid = ImageGrid(fig, 111, nrows_ncols=(features.shape[0] // 8, 8), axes_pad=0.1)
for f, (ax, feature) in enumerate(zip(grid, features)):
    ax.imshow(feature)
    ax.tick_params(which="both", bottom=False, labelbottom=False, labelleft=False, left=False)

fig.savefig("pvae_features.pdf")
plt.show()
