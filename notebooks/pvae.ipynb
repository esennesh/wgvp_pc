# %%
# %cd ..
# Out:
# /home/eli/AnacondaProjects/wgvp_pc

# %%
import hydra
import math
import matplotlib.pyplot as plt
import jax
import numpy as np
import numpyro
from omegaconf import OmegaConf
import rootutils
import sys

# %%
from src import test, train

# %%
with hydra.initialize(version_base="1.3", config_path="../configs", job_name="eval"):
    cfg = hydra.compose(config_name="eval.yaml", overrides=["ckpt_path=logs/train/runs/2025-08-04_15-48-59/saved/checkpoint-epoch100.npy", "hydra.runtime.output_dir=logs/test"], return_hydra_config=True)
    hydra.core.hydra_config.HydraConfig.instance().set_config(cfg)
    metrics, objects = test.test(cfg)

# %%
metrics
# Out:
# {'loss': -126.2057}

# %%
for data, target, indices in objects['datamodule'].test_dataloader():
    recons = objects['monad'](data)['x'].mean(axis=0).reshape(data.shape[0], 1, 28, 28)
    break

# %%
plt.imshow(recons[0].squeeze())

# %%
plt.imshow(data[0].squeeze())
