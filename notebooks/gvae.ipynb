# %%
# %cd ..
# Out:
# /home/eli/AnacondaProjects/wgvp_pc

# %%
import hydra
import math
import matplotlib.pyplot as plt
import jax
import numpy as np
import numpyro
from omegaconf import OmegaConf
import rootutils
import sys

# %%
from src import test, train

# %%
with hydra.initialize(version_base="1.3", config_path="../configs", job_name="eval"):
    cfg = hydra.compose(config_name="eval.yaml", overrides=["ckpt_path=logs/train/runs/2026-01-10_17-26-47/saved/checkpoint-epoch100.npy",
                                                            "+experiment=gvae", "hydra.runtime.output_dir=logs/test"], return_hydra_config=True)
    hydra.core.hydra_config.HydraConfig.instance().set_config(cfg)
    metrics, objects = test.test(cfg)

# %%
for data, _, _ in objects['datamodule'].test_dataloader():
    recons = objects['monad'](data)['obs'].mean(axis=0).reshape(data.shape[0], 1, 28, 28)
    break
# Out:
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:72: UserWarning: Found vars in model but not guide: {'obs'}
#   check_model_guide_match(model_trace, guide_trace)

# %%
plt.imshow(recons[0].squeeze())

# %%
plt.imshow(data[0].squeeze())

# %%
metrics
# Out:
# {'loss': np.float32(-116373.6), 'log_w': np.float32(116373.6)}
