# %%
# %cd ..
# Out:
# /home/eli/AnacondaProjects/wgvp_pc

# %%
import hydra
import math
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import numpy as np
import numpyro
from omegaconf import OmegaConf
import rootutils
import sys

# %%
from src import test, train

# %%
with hydra.initialize(version_base="1.3", config_path="../configs", job_name="eval"):
    cfg = hydra.compose(config_name="eval.yaml", overrides=["ckpt_path=logs/train/runs/2026-01-18_12-22-49/saved/checkpoint-epoch2000.npy",
                                                            "+experiment=pvae_vh16_reloo_conv", "hydra.runtime.output_dir=logs/test"], return_hydra_config=True)
    hydra.core.hydra_config.HydraConfig.instance().set_config(cfg)
    metrics, objects = test.test(cfg)

# %%
metrics
# Out:
# {'loss': np.float32(47847.965), 'log_w': np.float32(-41866.965)}

# %%
for data, _ in objects['datamodule'].test_dataloader():
    traces = objects['monad'](data)
    recons = traces['x'].mean(axis=0).reshape(data.shape[0], 1, 16, 16)
    break
# Out:
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:72: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)

# %%
plt.imshow(recons[0].squeeze(), cmap="Greys")

# %%
plt.imshow(data[0].squeeze(), cmap="Greys")

# %%
objects['monad'].render_model()

# %%
def r2(xs, xs_hat):
    squared_errors = ((xs - xs_hat) ** 2).sum()
    total_squares = ((xs - xs.mean(axis=0, keepdims=True)) ** 2).sum()
    return 1.0 - squared_errors / (total_squares + jnp.finfo("float64").eps)

def portion_zeros(zs):
    return (zs == 0).mean()

# %%
xs, xs_hat, zs = [], [], []

for data, _ in objects['datamodule'].test_dataloader():
    traces = objects['monad'](data)
    recons = traces['x'].mean(axis=0).reshape(data.shape[0], 1, 16, 16)
    xs.append(data)
    xs_hat.append(recons)
    zs.append(traces["z"])

xs = jnp.concatenate(xs, axis=0)
xs_hat = jnp.concatenate(xs_hat, axis=0)
zs = jnp.concatenate(zs, axis=1)
# Out:
# /home/eli/AnacondaProjects/wgvp_pc/src/inference/graphical.py:72: UserWarning: Found vars in model but not guide: {'x'}
#   check_model_guide_match(model_trace, guide_trace)

# %%
portion_zeros(zs)
# Out:
# Array(0.966413, dtype=float32)

# %%
r2(xs, xs_hat)
# Out:
# Array(0.20060915, dtype=float32)
